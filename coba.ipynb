# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("economic-damage-from-natural-disasters (1).csv")
df
# Out:
#                     Entity  Code  Year  \
# 0    All natural disasters   NaN  1900
# 1    All natural disasters   NaN  1901
# 2    All natural disasters   NaN  1902
# 3    All natural disasters   NaN  1903
# 4    All natural disasters   NaN  1904
# ..                     ...   ...   ...
# 556               Wildfire   NaN  2014
# 557               Wildfire   NaN  2015
# 558               Wildfire   NaN  2016
# 559               Wildfire   NaN  2017
# 560               Wildfire   NaN  2018
#
#      Total economic damage from natural disasters (US$)
# 0                                             30000000
# 1                                                    0
# 2                                                    0
# 3                                            480000000
# 4                                                    0
# ..                                                 ...
# 556                                          259000000
# ...

# %%
# Analisis deskriptif variabel Code
print(df["Entity"].value_counts())
# Out:
# All natural disasters    119
# Extreme weather           94
# Earthquake                83
# Flood                     69
# Drought                   49
# Wildfire                  44
# Extreme temperature       34
# Landslide                 34
# Volcanic activity         29
# Mass movement (dry)        5
# Impact                     1
# Name: Entity, dtype: int64

# %%
# Analisis deskriptif variabel Year
print(df["Year"].value_counts())
# Out:
# 2018    10
# 1992     9
# 2001     9
# 1997     9
# 1995     9
#         ..
# 1921     1
# 1905     1
# 1904     1
# 1901     1
# 1902     1
# Name: Year, Length: 119, dtype: int64

# %%
# Analisis deskriptif variabel Total economic damage from natural disasters (US$)
print(df["Total economic damage from natural disasters (US$)"].describe())
# Out:
# count    5.610000e+02
# mean     1.146966e+10
# std      3.199525e+10
# min      0.000000e+00
# 25%      6.850000e+07
# 50%      8.400000e+08
# 75%      5.444777e+09
# max      3.640932e+11
# Name: Total economic damage from natural disasters (US$), dtype: float64

# %%
#Membuat variabel baru untuk menyimpan data Entity setiap tahunnya
df["Entity Year"] = df["Entity"].astype("category")
df["Entity Year"] = df["Entity Year"].cat.set_categories([f"{year} - {year + 1}" for year in range(df["Year"].min(), df["Year"].max() + 1)])

# %%
df.head()
# Out:
#                   Entity  Code  Year  \
# 0  All natural disasters   NaN  1900
# 1  All natural disasters   NaN  1901
# 2  All natural disasters   NaN  1902
# 3  All natural disasters   NaN  1903
# 4  All natural disasters   NaN  1904
#
#    Total economic damage from natural disasters (US$) Entity Year
# 0                                           30000000          NaN
# 1                                                  0          NaN
# 2                                                  0          NaN
# 3                                          480000000          NaN
# 4                                                  0          NaN

# %%
us='Total economic damage from natural disasters (US$)'
xx=df[(df['Year']>2010 )&( df['Year']<2018)]
xx
# Out:
#                     Entity  Code  Year  \
# 111  All natural disasters   NaN  2011
# 112  All natural disasters   NaN  2012
# 113  All natural disasters   NaN  2013
# 114  All natural disasters   NaN  2014
# 115  All natural disasters   NaN  2015
# 116  All natural disasters   NaN  2016
# 117  All natural disasters   NaN  2017
# 160                Drought   NaN  2011
# 161                Drought   NaN  2012
# 162                Drought   NaN  2013
# 163                Drought   NaN  2014
# 164                Drought   NaN  2015
# 165                Drought   NaN  2016
# 166                Drought   NaN  2017
# 243             Earthquake   NaN  2011
# 244             Earthquake   NaN  2012
# 245             Earthquake   NaN  2013
# 246             Earthquake   NaN  2014
# 247             Earthquake   NaN  2015
# 248             Earthquake   NaN  2016
# 249             Earthquake   NaN  2017
# 277    Extreme temperature   NaN  2011
# 278    Extreme temperature   NaN  2012
# ...

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df, x=df['Year'], y=df["Total economic damage from natural disasters (US$)"])
# Out:
# <Axes: xlabel='Year', ylabel='Total economic damage from natural disasters (US$)'>

# %%
df["Entity Year"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 561 entries, 0 to 560
# Series name: Entity Year
# Non-Null Count  Dtype
# --------------  -----
# 0 non-null      category
# dtypes: category(1)
# memory usage: 5.7 KB

# %%
df["Entity Year"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 556    NaN
# 557    NaN
# 558    NaN
# 559    NaN
# 560    NaN
# Name: Entity Year, Length: 561, dtype: category
# Categories (119, object): ['1900 - 1901', '1901 - 1902', '1902 - 1903', '1903 - 1904', ..., '2015 - 2016', '2016 - 2017', '2017 - 2018', '2018 - 2019']

# %%
correlation = np.corrcoef(df["Year"], df["Total economic damage from natural disasters (US$)"])
correlation
# Out:
# array([[1.        , 0.31933123],
#        [0.31933123, 1.        ]])
